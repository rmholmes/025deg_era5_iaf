# %%
import xarray as xr
import numpy as np
import sys, os, glob

from dask.distributed import Client

# %%
# Load workers:
client = Client(n_workers=14)
client
# Out:
# <Client: 'tcp://127.0.0.1:38831' processes=14 threads=14, memory=63.00 GiB>

# %%
base = '/g/data/e14/rmh561/access-om2/input/ERA-5/IAF/'
vars = ['10u','10v','msdwlwrf','msdwswrf','msl','sp','2d','2t','msr','crr','lsrr']
months = ['05','06','07']
end_month = ['31','30','31']

for i, month in enumerate(months):
    for var in vars:
        print(var + ' ' + month)
        ds = xr.open_mfdataset(base + var + '/2023/tmp/' + var + '_era5t_oper_sfc_2023' + month + '*.nc', concat_dim="time", combine="nested",
                                 data_vars='minimal', coords='minimal', compat='override',
                                 parallel=True)
        ds.to_netcdf(base + var + '/2023/' + var + '_era5t_oper_sfc_2023' + month + '01-2023' + month + end_month[i] + '.nc')
# Out:
# 10u 05
# 10v 05
# msdwlwrf 05
# msdwswrf 05
# msl 05
# 10u 06
# 10v 06
